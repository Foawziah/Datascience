# %%
import pandas as pd #import pandas libary to create the dataframe

# %%
data=pd.read_csv("Scout24AG_pastadelivery_casestudy.csv",sep=';') # loading the data from the file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3536c08ad9a4> in <module>
# ----> 1 data=pd.read_csv("Scout24AG_pastadelivery_casestudy.csv",sep=';') # loading the data from the file
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data['pasta_price']=data["pasta_price"].str.replace(',','.') 
# the pasta price format is in string and decimal symbol was comma I replaced to point
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-77053c4feccd> in <module>
# ----> 1 data['pasta_price']=data["pasta_price"].str.replace(',','.')
#       2 # the pasta price format is in string and decimal symbol was comma I replaced to point
#
# NameError: name 'data' is not defined

# %%
data.pasta_price = data.pasta_price.astype("float64")
#casting the data type of pasta price to float
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4ed17e021139> in <module>
# ----> 1 data.pasta_price = data.pasta_price.astype("float64")
#       2 #casting the data type of pasta price to float
#
# NameError: name 'data' is not defined

# %%
most_purchased=data.groupby("hh_id")["pasta_price"].sum()
#sum of all pasta price according to House holder ID
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-db21f1957e1c> in <module>
# ----> 1 most_purchased=data.groupby("hh_id")["pasta_price"].sum()
#       2 #sum of all pasta price according to House holder ID
#
# NameError: name 'data' is not defined

# %%
mo=pd.DataFrame(most_purchased_customers)
#for ploting create a dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7000aa5fd757> in <module>
# ----> 1 mo=pd.DataFrame(most_purchased_customers)
#       2 #for ploting create a dataframe
#
# NameError: name 'most_purchased_customers' is not defined

# %%
mo.sort_values(by=['pasta_price'],ascending=False,inplace=True)
#sorting the price by ascending order
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-26a2c6dbcd83> in <module>
# ----> 1 mo.sort_values(by=['pasta_price'],ascending=False,inplace=True)
#       2 #sorting the price by ascending order
#
# NameError: name 'mo' is not defined

# %%
mo["hh_id"]=mo.index
#index added to dataframe as a column

# %%
mo
# Out:
#        pasta_price  hh_id
# hh_id
# 1493         55.36   1493
# 1511         51.03   1511
# 151          50.83    151
# 647          50.78    647
# 916          50.50    916
# ...            ...    ...
# 92           23.91     92
# 267          23.39    267
# 572          23.24    572
# 1921         21.74   1921
# 1917         19.24   1917
#
# [2000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
#libary for plotting

# %%
plt.figure(figsize=(16,5))
plt.scatter(mo['hh_id'],mo["pasta_price"])
plt.show()
#this plot show the number of purchase according to hhid

# %%
plt.xlabel('Purchased amount')
plt.ylabel('Number purchsed')
plt.hist(mo["pasta_price"])
plt.grid(True)
plt.show()
# histogram to shows the dense of purchase between customers

# %%
most_purchase_byCode=data["order_id"].mean()
most_purchase_byCode
#average of purchased according to orders
# Out:
# 10.5

# %%
ordered_byage=data.groupby("customer_age")["pasta_price"].sum()
ordered_byage=pd.DataFrame(ordered_byage)
plt.plot(ordered_byage.index,ordered_byage["pasta_price"])
#ploting the age of customers according to the most purchased

# %%
area_code_income=pd.DataFrame(data.groupby("area_code")["yearly_income"].sum())
area_code_income
#yearly income accoring to area-code
# Out:
#            yearly_income
# area_code
# 1              223489780
# 2              211323920
# 3              208071040
# 4              235836760
# 5              205123760

# %%
plt.bar([1,2,3,4,5],area_code_income['yearly_income'])
plt.show()
# plotting the yearly income in the base of area-code

# %%
order_income=pd.DataFrame(data.groupby("area_code")["order_id"].count())

# %%
nofi=pd.DataFrame(order_income)
labels = 'Area Code 1', 'Area Code 2', 'Area Code 3', 'Area Code 4','Area Code 5'
plt.pie(nofi['order_id'], labels=labels,autopct='%1.1f%%')
plt.show()
